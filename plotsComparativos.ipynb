# %% [markdown]
# ## Comparative plots between Matlab and Python modules partial results

# %%
from library import *
# Out:
# Using TensorFlow backend.

# %%
partialOutputPath = './partial_output_files/'

# %% [markdown]
# ### Module geraAreas() partial results comparison

# %%
time = np.loadtxt(partialOutputPath+'time_PY.csv')
area_c = np.loadtxt(partialOutputPath+'area_c_PY.csv')
alpha_mu_spot = np.loadtxt(partialOutputPath+'alpha_mu_spot_PY.csv')

alpha_mu_spot = np.reshape(alpha_mu_spot,(np.size(time),6,11))

rTotal = []

# %%
for i in range(11):

    fig, axs = plt.subplots(3, 2, sharex=True, sharey=True)

    fig.suptitle('Module geraAreas(): Each ring total area'+str(i+1))

    #Plotando as 6 classes do anel i
    arquivo = partialOutputPath+'alpha_mu_spot_ML'+str(i+1)+'.csv'
    alpha_mu_spot2 = np.loadtxt(arquivo)
    #print(arquivo)

    y=0
    rParcial = []

    for j in range(6):
        X = alpha_mu_spot[:,j,i]
        Y = alpha_mu_spot2[:,j]

        r = ma.corrcoef(ma.masked_invalid(X), ma.masked_invalid(Y))[0][1]
        
        rParcial.append(r)
        
        rLegend = f'r = {r:.2f}'
        #print(rLegend)
        #r = 'r = '+str(stats.pearsonr(alpha_mu_spot[:,j,i],alpha_mu_spot2[:,j])[0]) #retorna coeficiente de correlação e a probabilidade da correlação ser ao acaso.

        x = np.mod(j,2)

        axs[y*1,x].plot(X,Y, 'b.')
        axs[y*1,x].scatter(X,Y)
        axs[y*1,x].legend([rLegend], loc=0)
        axs[y*1,x].set_xlim([np.min(alpha_mu_spot),np.max(alpha_mu_spot)])
        axs[y*1,x].set_ylim([np.min(alpha_mu_spot2),np.max(alpha_mu_spot2)])
        ##plt.legend(loc='best')

        y += x

        #print('r = ',stats.pearsonr(alpha_mu_spot[:,0,i],alpha_mu_spot2[:,0]))    

    for ax in axs.flat:
        ax.set(xlabel='Python', ylabel='Matlab')

    ## Hide x labels and tick labels for top plots and y ticks for right plots.
    for ax in axs.flat:
        ax.label_outer()
    
    file = (partialOutputPath+'Ring'+str(i+1)+'.png')
    plt.savefig(file, transparent = True)
    rTotal.append(rParcial)

# %%
rTotal = np.asarray(rTotal)
fig, [ax1,ax2] = plt.subplots(1,2,figsize=(15, 7), sharey=True)

for i in range(6):
    ax1.plot(rTotal[:,i],'.-')
    ax1.set_ylim([0.8,1.2])
    
ax1.set_xlabel('Rings number (from the innermost to the outermost)')
ax1.set_ylabel('Correlation Coefficient')

ax1.set_title('Correlation Coefficient between Matlab and Python data for each size class')
ax1.legend(['small active region',
            'small median active region',
            'big median active region',
            'big active region',
            'penumbra region',
            'umbra region'],loc=3)

for i in range(11):
    ax2.plot(rTotal[i,:],'.-')
    ax2.set_ylim([0.8,1.2])

ax2.set_xlabel('Size Classes (from small regions to umbra)')
ax2.set_ylabel('Correlation Coeficient')

ax2.set_title('Correlation Coeficient between Matlab and Python data for each ring')

ax2.legend(['1st (innermost) Ring',
            '2nd Ring',
            '3rd Ring',
            '4th Ring',
            '5th Ring',
            '6th Ring',
            '7th Ring',
            '8th Ring',
            '9th Ring',
            '10th Ring',
            '11th Ring'],loc=4)

# %% [markdown]
# ### Module check_areas() partial results comparison

# %%
time = np.loadtxt(partialOutputPath+'check_areas_time_PY.csv')
area_c = np.loadtxt(partialOutputPath+'check_areas_area_c_PY.csv')
alpha_mu_spot = np.loadtxt(partialOutputPath+'check_areas_alpha_mu_spot_PY.csv')

alpha_mu_spot = np.reshape(alpha_mu_spot,(np.size(time),6,11))

rTotal_ca = []

# %%
for i in range(11):

    fig, axs = plt.subplots(3, 2, sharex=True, sharey=True)

    fig.suptitle('Module check_areas(): Each ring total area'+str(i+1))

    #Plotando as 6 classes do anel i
    arquivo = partialOutputPath+'alpha_mu_spot_ML'+str(i+1)+'.csv'
    alpha_mu_spot2 = np.loadtxt(arquivo)
    #print(arquivo)

    y=0
    rParcial = []

    for j in range(6):
        X = alpha_mu_spot[:,j,i]
        Y = alpha_mu_spot2[:,j]

        r = ma.corrcoef(ma.masked_invalid(X), ma.masked_invalid(Y))[0][1]
        
        rParcial.append(r)
        
        rLegend = f'r = {r:.2f}'
        #print(rLegend)
        #r = 'r = '+str(stats.pearsonr(alpha_mu_spot[:,j,i],alpha_mu_spot2[:,j])[0]) #retorna coeficiente de correlação e a probabilidade da correlação ser ao acaso.

        x = np.mod(j,2)

        axs[y*1,x].plot(X,Y, 'b.')
        axs[y*1,x].scatter(X,Y)
        axs[y*1,x].legend([rLegend], loc=0)
        axs[y*1,x].set_xlim([np.min(alpha_mu_spot),np.max(alpha_mu_spot)])
        axs[y*1,x].set_ylim([np.min(alpha_mu_spot2),np.max(alpha_mu_spot2)])
        ##plt.legend(loc='best')

        y += x

        #print('r = ',stats.pearsonr(alpha_mu_spot[:,0,i],alpha_mu_spot2[:,0]))    

    for ax in axs.flat:
        ax.set(xlabel='Python', ylabel='Matlab')

    ## Hide x labels and tick labels for top plots and y ticks for right plots.
    for ax in axs.flat:
        ax.label_outer()
    
    file = (partialOutputPath+'check_area_Ring'+str(i+1)+'.png')
    plt.savefig(file, transparent = True)
    rTotal_ca.append(rParcial)

# %%
rTotal = np.asarray(rTotal_ca)

fig, [ax1,ax2] = plt.subplots(1,2,figsize=(15, 7), sharey=True)

for i in range(6):
    ax1.plot(rTotal[:,i],'.-')
    ax1.set_ylim([0.6,1.2])
    
ax1.set_xlabel('Rings number (from the innermost to the outermost)')
ax1.set_ylabel('Correlation Coefficient')

ax1.set_title('Correlation Coefficient between Matlab and Python data for each active region size class')
ax1.legend(['small active region',
            'small median active region',
            'big median active region',
            'big active region',
            'penumbra region',
            'umbra region'],loc=3)

for i in range(11):
    ax2.plot(rTotal[i,:],'.-')
    ax2.set_ylim([0.6,1.2])

ax2.set_xlabel('Size Classes (from small regions to umbra)')
ax2.set_ylabel('Correlation Coefficient')

ax2.set_title('Correlation Coefficient between Matlab and Python data for each solar disk ring')

ax2.legend(['1st (innermost) Ring',
            '2nd Ring',
            '3rd Ring',
            '4th Ring',
            '5th Ring',
            '6th Ring',
            '7th Ring',
            '8th Ring',
            '9th Ring',
            '10th Ring',
            '11th Ring'],loc=4)

# %% [markdown]
# ### Module model_mdi_02_03() partial results comparison: standarized and not standarized RNN input data

# %%
P_py = np.loadtxt(partialOutputPath+'P_PY.csv')
T_py = np.loadtxt(partialOutputPath+'T_PY.csv')
P_ml = np.loadtxt(partialOutputPath+'P_ML.csv')
T_ml = np.loadtxt(partialOutputPath+'T_ML.csv')

Pn_py = np.loadtxt(partialOutputPath+'pn_PY.csv')
Tn_py = np.loadtxt(partialOutputPath+'tn_PY.csv')
Pn_ml = np.loadtxt(partialOutputPath+'pn_ML.csv')
Tn_ml = np.loadtxt(partialOutputPath+'tn_ML.csv')

Pn_py = Pn_py.transpose()

series_size = T_ml.size

rTotal = []
rnTotal = []

# %%
print(P_ml.shape)
print(P_py.shape)
print(Pn_ml.shape)
print(Pn_py.shape)
# Out:
# (40, 587)
# (40, 587)
# (40, 587)
# (40, 587)

# %%
for i in range(P_py.shape[0]):
    X = P_py[i,:]
    Y = P_ml[i,:]
    r = ma.corrcoef(ma.masked_invalid(X), ma.masked_invalid(Y))[0][1]
    rTotal.append(r)

    Xn = Pn_py[i,:]
    Yn = Pn_ml[i,:]
    rn = ma.corrcoef(ma.masked_invalid(Xn), ma.masked_invalid(Yn))[0][1]
    rnTotal.append(rn)

fig, [ax1,ax2] = plt.subplots(1,2, figsize=(15, 7), sharey=True, gridspec_kw={'wspace': 0})
fig.suptitle('Correlation Coefficient between Matlab and Python gennerated RNN input data')
ax1.plot(rTotal,'b.-')
ax1.set_title('Not Standarized Input')
ax1.set_ylabel('Correlation Coefficient')
ax2.plot(rnTotal,'b.-')    
ax2.set_title('Standarized Input')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-77277dfac3c9> in <module>
#       7     Xn = Pn_py[i,:]
#       8     Yn = Pn_ml[i,:]
# ----> 9     rn = ma.corrcoef(ma.masked_invalid(Xn), ma.masked_invalid(Yn))[0][1]
#      10     rnTotal.append(rn)
#      11
#
# ~\Anaconda3\lib\site-packages\numpy\ma\extras.py in corrcoef(x, y, rowvar, bias, allow_masked, ddof)
#    1404         warnings.warn(msg, DeprecationWarning, stacklevel=2)
#    1405     # Get the data
# -> 1406     (x, xnotmask, rowvar) = _covhelper(x, y, rowvar, allow_masked)
#    1407     # Compute the covariance matrix
#    1408     if not rowvar:
#
# ~\Anaconda3\lib\site-packages\numpy\ma\extras.py in _covhelper(x, y, rowvar, allow_masked)
#    1272                     x._sharedmask = False
#    1273                     y._sharedmask = False
# -> 1274         x = ma.concatenate((x, y), axis)
#    1275         xnotmask = np.logical_not(np.concatenate((xmask, ymask), axis)).astype(int)
#    1276     x -= x.mean(axis=rowvar)[tup]
#
# ~\Anaconda3\lib\site-packages\numpy\ma\core.py in concatenate(arrays, axis)
#    6773
#    6774     """
# -> 6775     d = np.concatenate([getdata(a) for a in arrays], axis)
#    6776     rcls = get_masked_subclass(*arrays)
#    6777     data = d.view(rcls)
#
# ValueError: all the input array dimensions except for the concatenation axis must match exactly

# %%
for i in range(10):
    plt.figure(i)
    plt.plot(range(P_py.shape[0]),P_py[:,i],'b*',range(P_py.shape[0]),P_ml[:,i],'r-')
    plt.show

# %%
T_ml = T_ml.reshape(-1,1)
T_py = T_py.reshape(-1,1)

plt.plot(range(series_size),T_py,'b-',range(series_size),T_ml,'g.')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ### Module rnn() standarized RNN input data

# %%
for i in range(Pn_py.shape[0]):
    plt.figure(i)
    plt.plot(range(series_size),Pn_py[i,:],'b*-',range(series_size),Pn_ml[i,:],'r*-')
    plt.show

plt.figure(i+1)
plt.plot(range(series_size),Tn_py,'g*',range(series_size),Tn_ml,'b-')
plt.show
# Out:
# C:\Users\Ami\Anaconda3\lib\site-packages\matplotlib\pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# <function matplotlib.pyplot.show(*args, **kw)>
